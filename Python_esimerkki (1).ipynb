# %%
from bs4 import BeautifulSoup
import requests
from fake_useragent import UserAgent

# %%
ua = UserAgent()
header = {'user-agent':ua.chrome}
url = 'https://oikio.fi/asiantuntijatiimi/'
page = requests.get(url,headers=header)
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
#
# <html lang="fi">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Tutustu asiantuntijatiimiimme » OIKIO</title>
# <link href="https://oikio.fi/asiantuntijatiimi/" hreflang="fi" rel="alternate"/>
# <link href="https://oikio.fi/en/team/" hreflang="en" rel="alternate"/>
# <!-- This site is optimized with the Yoast SEO plugin v12.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="Asiantuntijatiimimme koostuu kolmesta tiimistä: Data &amp; Programmatic, SEO ja PPC. Tutustu tästä tarkemmin meidän asiantuntijoihin." name="description">
# <link href="https://oikio.fi/asiantuntijatiimi/" rel="canonical"/>
# <meta content="fi_FI" property="og:locale">
# <meta content="article" property="og:type">
# <meta content="Tutustu asiantuntijatiimiimme » OIKIO" property="og:title"/>
# <meta content="Asiantuntijatiimimme koostuu kolmesta tiimistä: Data &amp; Programmatic, SEO ja PPC. Tutustu tästä tarkemmin meidän asiantuntijoihin." property="og:description"/>
# <meta content="https://oikio.fi/asiantuntijatiimi/" property="og:url"/>
# <meta content="OIKIO" property="og:site_name"/>
# <meta content="1252320914943461" property="fb:app_id"/>
# <meta content="https://oikio.fi/wp-content/uploads/2017/05/HLaL_blogger_hero.jpg" property="og:image"/>
# <meta content="https://oikio.fi/wp-content/uploads/2017/05/HLaL_blogger_hero.jpg" property="og:image:secure_url"/>
# <meta content="1000" property="og:image:width"/>
# <meta content="333" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Asiantuntijatiimimme koostuu kolmesta tiimistä: Data &amp; Programmatic, SEO ja PPC. Tutustu tästä tarkemmin meidän asiantuntijoihin." name="twitter:description"/>
# <meta content="Tutustu asiantuntijatiimiimme » OIKIO" name="twitter:title"/>
# <meta content="https://oikio.fi/app/uploads/2017/05/HLaL_blogger_hero.jpg" name="twitter:image"/>
# <script class="yoast-schema-graph yoast-schema-graph--main" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://oikio.fi/#website","url":"https://oikio.fi/","name":"OIKIO","potentialAction":{"@type":"SearchAction","target":"https://oikio.fi/search/{search_term_string}","query-input":"required name=search_term_string"}},{"@type":"WebPage","@id":"https://oikio.fi/asiantuntijatiimi/#webpage","url":"https://oikio.fi/asiantuntijatiimi/","inLanguage":"fi","name":"Tutustu asiantuntijatiimiimme &raquo; OIKIO","isPartOf":{"@id":"https://oikio.fi/#website"},"datePublished":"2019-01-25T20:17:36+00:00","dateModified":"2019-07-29T10:23:35+00:00","description":"Asiantuntijatiimimme koostuu kolmesta tiimist\u00e4: Data & Programmatic, SEO ja PPC. Tutustu t\u00e4st\u00e4 tarkemmin meid\u00e4n asiantuntijoihin."}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="//code.jquery.com" rel="dns-prefetch"/>
# <link href="/wp-includes/css/dist/block-library/style.min.css?ver=5.2.5" rel="stylesheet"/>
# <link href="/wp-content/plugins/instagram-feed/css/sb-instagram.min.css?ver=1.10.2" rel="stylesheet"/>
# <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/wp-content/themes/oikio/dist/styles/main-4c5a77f475.css" rel="stylesheet"/>
# <meta content="WPML ver:4.1.1 stt:1,18;" name="generator"/>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KZ28V6');</script>
# <!-- End Google Tag Manager --></meta></meta></meta></head>
# <body class="page page-id-6196 asiantuntijatiimi page-child">
# <!--[if IE]>
#       <div class="alert alert-warning">
#         You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.      </div>
#     <![endif]-->
# <header class="banner nav-down has-contact">
# <div class="container-fluid">
# <div class="row">
# <div class="menu-container">
# <div class="logo-container">
# <a class="brand" href="https://oikio.fi/">
# <img alt="Oikio - Digital Performance Agency" src="/app/themes/oikio/dist/images/logo.svg"/>
# </a>
# </div>
# <nav class="nav-primary">
# <ul class="nav" id="menu-main-menu-fi"><li class="menu-item menu-item-has-children menu-asiakkaille"><a href="https://oikio.fi/palvelut/">Asiakkaille</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-has-children menu-auditoinnit"><a href="https://oikio.fi/auditoinnit/">Auditoinnit</a>
# <ul class="sub-menu">
# <li class="menu-item menu-sem-auditointi"><a href="https://oikio.fi/auditoinnit/sem/">SEM-auditointi</a></li>
# </ul>
# </li>
# <li class="menu-item menu-referenssit"><a href="https://oikio.fi/referenssit/">Referenssit</a></li>
# <li class="menu-item menu-koulutukset"><a href="https://oikio.fi/palvelut/koulutukset/">Koulutukset</a></li>
# <li class="menu-item menu-online-mainonta"><a href="https://oikio.fi/palvelut/mainonta/">Online-mainonta</a></li>
# <li class="menu-item menu-hakukoneoptimointi"><a href="https://oikio.fi/palvelut/hakukoneoptimointi/">Hakukoneoptimointi</a></li>
# <li class="menu-item menu-konversio-optimointi"><a href="https://oikio.fi/palvelut/konversio-optimointi/">Konversio-optimointi</a></li>
# <li class="menu-item menu-web-analytiikka"><a href="https://oikio.fi/palvelut/web-analytiikka/">Web-analytiikka</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-has-children menu-asiantuntijoille"><a href="https://oikio.fi/tyopaikat/">Asiantuntijoille</a>
# <ul class="sub-menu">
# <li class="menu-item menu-ppc-consultant"><a href="https://oikio.fi/tyopaikat/ppc-consultant/">PPC Consultant</a></li>
# <li class="menu-item menu-seo-consultant"><a href="https://oikio.fi/tyopaikat/seo-consultant/">SEO Consultant</a></li>
# <li class="menu-item menu-programmatic-consultant"><a href="https://oikio.fi/tyopaikat/programmatic-consultant/">Programmatic Consultant</a></li>
# <li class="menu-item menu-web-analyst"><a href="https://oikio.fi/tyopaikat/web-analyst/">Web Analyst</a></li>
# </ul>
# </li>
# <li class="menu-item menu-blogi"><a href="https://oikio.fi/blogi/">Blogi</a></li>
# <li class="active menu-item menu-item-has-children menu-yritys"><a href="https://oikio.fi/yritys/">Yritys</a>
# <ul class="sub-menu">
# <li class="menu-item menu-laskutustiedot"><a href="https://oikio.fi/laskutustiedot/">Laskutustiedot</a></li>
# <li class="menu-item menu-medialle"><a href="https://oikio.fi/medialle/">Medialle</a></li>
# <li class="menu-item menu-johto-ja-hallitus"><a href="https://oikio.fi/yritys/johto-ja-hallitus/">Johto ja hallitus</a></li>
# <li class="menu-item menu-elementtien-sanakirja"><a href="https://oikio.fi/elementit/">Elementtien sanakirja</a></li>
# <li class="active menu-item menu-asiantuntijatiimi"><a aria-current="page" href="https://oikio.fi/asiantuntijatiimi/">Asiantuntijatiimi</a></li>
# </ul>
# </li>
# <li class="finnish-button active menu-item menu-finland"><a>Finland</a></li>
# <li class="english-button menu-item menu-english"><a>English</a></li>
# <li class="menu-item menu-ota-yhteytta"><a href="/ota-yhteytta/" title="oikio-popup">Ota yhteyttä</a></li>
# <li class="menu-item menu-hae-toihin"><a href="https://oikio.typeform.com/to/vcFqHU" rel="noopener noreferrer" target="_blank" title="oikio-popup-rekry">Hae töihin</a></li>
# </ul> </nav>
# <button class="hamburger hamburger--spring" type="button">
# <span class="hamburger-box">
# <span class="hamburger-inner"></span>
# </span>
# </button>
# </div>
# </div>
# </div>
# </header>
# <div class="mobile-menu">
# <ul class="nav" id="menu-main-menu-fi-1"><li class="menu-item menu-item-has-children menu-asiakkaille"><a href="https://oikio.fi/palvelut/">Asiakkaille</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-has-children menu-auditoinnit"><a href="https://oikio.fi/auditoinnit/">Auditoinnit</a>
# <ul class="sub-menu">
# <li class="menu-item menu-sem-auditointi"><a href="https://oikio.fi/auditoinnit/sem/">SEM-auditointi</a></li>
# </ul>
# </li>
# <li class="menu-item menu-referenssit"><a href="https://oikio.fi/referenssit/">Referenssit</a></li>
# <li class="menu-item menu-koulutukset"><a href="https://oikio.fi/palvelut/koulutukset/">Koulutukset</a></li>
# <li class="menu-item menu-online-mainonta"><a href="https://oikio.fi/palvelut/mainonta/">Online-mainonta</a></li>
# <li class="menu-item menu-hakukoneoptimointi"><a href="https://oikio.fi/palvelut/hakukoneoptimointi/">Hakukoneoptimointi</a></li>
# <li class="menu-item menu-konversio-optimointi"><a href="https://oikio.fi/palvelut/konversio-optimointi/">Konversio-optimointi</a></li>
# <li class="menu-item menu-web-analytiikka"><a href="https://oikio.fi/palvelut/web-analytiikka/">Web-analytiikka</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-has-children menu-asiantuntijoille"><a href="https://oikio.fi/tyopaikat/">Asiantuntijoille</a>
# <ul class="sub-menu">
# <li class="menu-item menu-ppc-consultant"><a href="https://oikio.fi/tyopaikat/ppc-consultant/">PPC Consultant</a></li>
# <li class="menu-item menu-seo-consultant"><a href="https://oikio.fi/tyopaikat/seo-consultant/">SEO Consultant</a></li>
# <li class="menu-item menu-programmatic-consultant"><a href="https://oikio.fi/tyopaikat/programmatic-consultant/">Programmatic Consultant</a></li>
# <li class="menu-item menu-web-analyst"><a href="https://oikio.fi/tyopaikat/web-analyst/">Web Analyst</a></li>
# </ul>
# </li>
# <li class="menu-item menu-blogi"><a href="https://oikio.fi/blogi/">Blogi</a></li>
# <li class="active menu-item menu-item-has-children menu-yritys"><a href="https://oikio.fi/yritys/">Yritys</a>
# <ul class="sub-menu">
# <li class="menu-item menu-laskutustiedot"><a href="https://oikio.fi/laskutustiedot/">Laskutustiedot</a></li>
# <li class="menu-item menu-medialle"><a href="https://oikio.fi/medialle/">Medialle</a></li>
# <li class="menu-item menu-johto-ja-hallitus"><a href="https://oikio.fi/yritys/johto-ja-hallitus/">Johto ja hallitus</a></li>
# <li class="menu-item menu-elementtien-sanakirja"><a href="https://oikio.fi/elementit/">Elementtien sanakirja</a></li>
# <li class="active menu-item menu-asiantuntijatiimi"><a aria-current="page" href="https://oikio.fi/asiantuntijatiimi/">Asiantuntijatiimi</a></li>
# </ul>
# </li>
# <li class="finnish-button active menu-item menu-finland"><a>Finland</a></li>
# <li class="english-button menu-item menu-english"><a>English</a></li>
# <li class="menu-item menu-ota-yhteytta"><a href="/ota-yhteytta/" title="oikio-popup">Ota yhteyttä</a></li>
# <li class="menu-item menu-hae-toihin"><a href="https://oikio.typeform.com/to/vcFqHU" rel="noopener noreferrer" target="_blank" title="oikio-popup-rekry">Hae töihin</a></li>
# </ul> <div class="mobile-footer">
# <ul class="footer-extra-links">
# <li class="menu-link"><a href="/tyopaikat/">Avoimet työpaikat</a></li>
# <li class="menu-link"><a href="/ota-yhteytta/">Ota yhteyttä</a></li>
# <li class="menu-link"><a href="/media/">Medialle</a></li>
# <li class="menu-link"><a href="/elementit/">Elementit</a></li>
# </ul>
# <div class="footer-sub">
# <div class="footer-lang-menu">
# <ul><li><a href="https://oikio.fi/asiantuntijatiimi/"><img alt="fi" height="28" src="https://oikio.fi/wp-content/themes/oikio/dist/images/lang__fi.svg" width="28"/></a></li><li><a href="https://oikio.fi/en/team/"><img alt="en" height="28" src="https://oikio.fi/wp-content/themes/oikio/dist/images/lang__en.svg" width="28"/></a></li></ul>
# </div>
# <div class="footer-some">
# <ul class="footer-some-links">
# <li><a class="some-link facebook" href="https://www.facebook.com/oikioagency"><img src="/app/themes/oikio/dist/images/facebook.svg"/></a></li> <li><a class="some-link twitter" href="https://twitter.com/oikioagency"><img src="/app/themes/oikio/dist/images/twitter.svg"/></a></li> <li><a class="some-link instagram" href="https://www.instagram.com/oikioagency/"><img src="/app/themes/oikio/dist/images/instagram.svg"/></a></li> <li><a class="some-link linkedin" href="https://www.linkedin.com/company/oikio-digital-performance-agency/"><img src="/app/themes/oikio/dist/images/linkedin-linkki.svg"/></a></li> </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- <div class="mobile-contact-button">
#   <a href="#" class="btn-mobile btn-orange">Ota yhteyttä</a>
# </div> -->
# <div class="wrap container-fluid" role="document">
# <div class="content row">
# <main class="main-content">
# <!-- <div class="container">
#   <div class="row">
#     <div class="col-xs-12 col-md-12">
#       <div class="page-header">
#         <h1>Asiantuntijatiimi</h1>
#       </div>
#     </div>
#   </div>
# </div> -->
# <div class="container-fluid" id="" style=" margin-bottom: 0px">
# <div class="row">
# <div class="col-xs-12 block-header_full">
# <div class="content bg-light-orange" style="background-image: url('');">
# <div class="content-inner">
# <div class="header-text">
# <h1 class="header-title-full">Asiantuntijamme</h1> <div class="header-sub"><p>Asiantuntijamme muodostavat asiantuntijatiimin, jonka jokainen asiakkaamme saa käyttöönsä. Me emme halua, että sinä asiakkaana tai me yrityksenä olisimme riippuvaisia yhdestä asiantuntijasta. Tästä syystä meidän yksi keskeisimmistä tavoitteista on pitää tiimityöskentely, dokumentaatio ja kommunikaatiokykymme huipputasolla.</p></div></div></div></div></div></div></div></main></div></div></body></html>
#
#
#
#
#
# <div class="container-fluid" id="" style=" margin-bottom: 0px">
# <div class="row">
# <div class="col-xs-12 block-color_lift_two">
# <div class="content bg-darkest-blue">
# <div class="content-inner">
# <div class="row">
# <div class="col-xs-12 col-md-12">
# <h3 class="content-title">Data &amp; Programmatic -tiimi</h3> </div>
# </div>
# <div class="row">
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/taru-paavola/">
# <div class="image">
# <img src="/wp-content/uploads/2019/11/taru_pieni.jpg"/>
# </div>
# <span class="name">Taru Paavola</span>
# <span class="title">Junior Paid Social &amp; Programmatic Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/aleksi/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Aleksi.jpg"/>
# </div>
# <span class="name">Aleksi Rastas</span>
# <span class="title">Senior Web Analyst</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/jyri-vuorinen/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Jyri.jpg"/>
# </div>
# <span class="name">Jyri Vuorinen</span>
# <span class="title">Senior Web Analyst</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/selja-selenius/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Selja.jpg"/>
# </div>
# <span class="name">Selja Selenius</span>
# <span class="title">Lead Programmatic Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/krista-tikka/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Krista.jpg"/>
# </div>
# <span class="name">Krista Tikka</span>
# <span class="title">Lead Paid Social Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/ilpo-ryynanen/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Ilpo.jpg"/>
# </div>
# <span class="name">Ilpo Ryynänen</span>
# <span class="title">Head of Data &amp; Programmatic</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid" id="" style=" margin-bottom: 0px">
# <div class="row">
# <div class="col-xs-12 block-color_lift_two">
# <div class="content bg-dark-green">
# <div class="content-inner">
# <div class="row">
# <div class="col-xs-12 col-md-12">
# <h3 class="content-title">SEO-tiimi</h3> </div>
# </div>
# <div class="row">
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/iiris-lagus/">
# <div class="image">
# <img src="/wp-content/uploads/2019/10/iiris-lagus.jpg"/>
# </div>
# <span class="name">Iiris Lagus</span>
# <span class="title">SEO Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/essi-martevo/">
# <div class="image">
# <img src="/wp-content/uploads/2019/10/essi-martevo.jpg"/>
# </div>
# <span class="name">Essi Martevo</span>
# <span class="title">SEO Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/frans-astala/">
# <div class="image">
# <img src="/wp-content/uploads/2019/05/frans.jpg"/>
# </div>
# <span class="name">Frans Astala</span>
# <span class="title">SEO Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/henri-tamminen/">
# <div class="image">
# <img src="/wp-content/uploads/2019/10/henkka-tamminen.jpg"/>
# </div>
# <span class="name">Henri Tamminen</span>
# <span class="title">SEO Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/joonas-kantoluoto/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/JoonasK.jpg"/>
# </div>
# <span class="name">Joonas Kantoluoto</span>
# <span class="title">SEO Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/satu-brandt/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/SatuB.jpg"/>
# </div>
# <span class="name">Satu Brandt</span>
# <span class="title">SEO Consultant &amp; Team Lead</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/emilia-lahti/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Emilia.jpg"/>
# </div>
# <span class="name">Emilia Lahti</span>
# <span class="title">SEO Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/joona-tuunanen/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Joona.jpg"/>
# </div>
# <span class="name">Joona Tuunanen</span>
# <span class="title">Head of SEO</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid" id="" style=" margin-bottom: 0px">
# <div class="row">
# <div class="col-xs-12 block-color_lift_two">
# <div class="content bg-light-orange">
# <div class="content-inner">
# <div class="row">
# <div class="col-xs-12 col-md-12">
# <h3 class="content-title">PPC-tiimi</h3> </div>
# </div>
# <div class="row">
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/jaani-saulamaa-3/">
# <div class="image">
# <img src="/wp-content/uploads/2019/10/jaani-saulamaa.jpg"/>
# </div>
# <span class="name">Jaani Saulamaa</span>
# <span class="title">PPC Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/iiro-heiskanen/">
# <div class="image">
# <img src="/wp-content/uploads/2019/05/iiro.jpg"/>
# </div>
# <span class="name">Iiro Heiskanen</span>
# <span class="title">PPC Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/jaana-rasanen/">
# <div class="image">
# <img src="/wp-content/uploads/2019/05/jaana.jpg"/>
# </div>
# <span class="name">Jaana Räsänen</span>
# <span class="title">PPC Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/joonas-savolainen/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/JoonasS.jpg"/>
# </div>
# <span class="name">Joonas Savolainen</span>
# <span class="title">PPC Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/joachim-granberg/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Joachim.jpg"/>
# </div>
# <span class="name">Joachim Granberg</span>
# <span class="title">Senior PPC Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/mirkka-mussalo/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Mirkka.jpg"/>
# </div>
# <span class="name">Mirkka Mussalo</span>
# <span class="title">PPC Consultant &amp; Team Lead</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/saad-hafeez/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Saad.jpg"/>
# </div>
# <span class="name">Saad Hafeez</span>
# <span class="title">PPC Consultant</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/juha-vihervas/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Juha.jpg"/>
# </div>
# <span class="name">Juha Viherväs</span>
# <span class="title">Head of PPC</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid" id="" style=" margin-bottom: 0px">
# <div class="row">
# <div class="col-xs-12 block-color_lift_two">
# <div class="content bg-darkest-blue">
# <div class="content-inner">
# <div class="row">
# <div class="col-xs-12 col-md-12">
# <h3 class="content-title">Hallinto-tiimi</h3> </div>
# </div>
# <div class="row">
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/satu-tamminen/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/SatuT.jpg"/>
# </div>
# <span class="name">Satu Tamminen</span>
# <span class="title">Business Controller</span>
# </a>
# </div>
# <div class="col-xs-12 col-md-6 col-lg-4 single-person">
# <a href="https://oikio.fi/asiantuntijatiimi/niilo-relander/">
# <div class="image">
# <img src="/wp-content/uploads/2019/01/Niilo.jpg"/>
# </div>
# <span class="name">Niilo Relander</span>
# <span class="title">CEO</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- /.main -->
# <!-- /.content -->
# <!-- /.wrap -->
# <footer class="content-info">
# <!-- First footer row -->
# <div class="container footer-block" id="footer-info">
# <div class="row">
# <div class="col-xs-12 col-xl-3 col-md-3">
# <div class="oikio-logo" style="background-image: url('/app/themes/oikio/dist/images/logo.svg');"></div>
# </div>
# <div class="col-xs-12 col-xl-6 col-md-6">
# <div class="footer-description">
# <p>OIKIO Digital Performance Agency Oy on digitaalisen myynnin ja markkinoinnin asiantuntijatoimisto. OIKIO on erikoistunut web-analytiikkaan, hakukoneoptimointiin ja online-mainonnan optimointiin. OIKIOn asiakkaita ovat suuret ja keskisuuret B2B- ja B2C-yritykset.</p>
# </div>
# </div>
# <div class="col-xs-12 col-xl-3 col-md-3">
# <div class="extra-logos">
# <div class="logo-vuodentoimisto" style="background-image: url('/app/themes/oikio/dist/images/toimisto2019.jpg');"></div>
# <div class="logo-vuodentoimisto" style="background-image: url('/app/themes/oikio/dist/images/vuodentoimisto.svg');"></div>
# </div>
# </div>
# </div>
# </div>
# <!-- Footer row with links -->
# <div class="container footer-block" id="footer-links">
# <div class="row">
# <div class="col-xs-12 col-lg-3 link-row">
# <ul class="footer-link-menu">
# <label>Palvelut<span class="handle"></span></label>
# <li><a href="/palvelut/web-analytiikka/" target="">Web-analytiikka</a></li>
# <li><a href="/palvelut/konversio-optimointi/" target="">Konversio-optimointi</a></li>
# <li><a href="/palvelut/hakukoneoptimointi/" target="">Hakukoneoptimointi</a></li>
# <li><a href="/palvelut/mainonta/hakusanamainonta/" target="">Hakusanamainonta</a></li>
# <li><a href="/palvelut/mainonta/ohjelmallinen/" target="">Ohjelmallinen display-mainonta</a></li>
# <li><a href="/palvelut/mainonta/facebook-mainonta/" target="">Facebook-mainonta</a></li>
# </ul>
# </div>
# <div class="col-xs-12 col-lg-3 link-row">
# <ul class="footer-link-menu">
# <label>Työpaikat<span class="handle"></span></label>
# <li><a href="/tyopaikat/web-analyst/" target="">Web Analyst</a></li>
# <li><a href="/tyopaikat/seo-consultant/" target="">SEO Consultant</a></li>
# <li><a href="/tyopaikat/ppc-consultant/" target="">PPC Consultant</a></li>
# <li><a href="https://oikio.fi/tyopaikat/junior-ppc-consultant/" target="">Junior PPC Consultant</a></li>
# <li><a href="/tyopaikat/programmatic-consultant/" target="">Programmatic Consultant</a></li>
# </ul>
# </div>
# <div class="col-xs-12 col-lg-3 link-row">
# <ul class="footer-link-menu">
# <label>Yritys<span class="handle"></span></label>
# <li><a href="/asiantuntijatiimi/" target="">Asiantuntijatiimi</a></li>
# <li><a href="/yritys/johto-ja-hallitus/" target="">Johto ja Hallitus</a></li>
# <li><a href="/media/" target="">Medialle</a></li>
# <li><a href="/laskutustiedot/" target="">Laskutustiedot</a></li>
# <li><a href="/tietosuojaseloste/" target="">Tietosuojaseloste</a></li>
# </ul>
# </div>
# <div class="col-xs-12 col-lg-3 link-row">
# <ul class="footer-link-menu">
# <label>Blogi<span class="handle"></span></label>
# <li><a href="/blogi/#ajankohtaista" target="">Ajankohtaista</a></li>
# <li><a href="/blogi/" target="">Asiantuntija-artikkelit</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="container footer-block" id="footer-company-info">
# <div class="row">
# <div class="col-xs-12 col-lg-4 footer-col">
# <h4 class="footer-title" style="color: #ff541d;">Tilaa uutiskirje</h4>
# <form action="https://hooks.zapier.com/hooks/catch/1862021/xkk7h4/" id="oikio-newsletter-form">
# <input id="hidClientID2" name="hidClientID2" type="hidden"/>
# <label class="newsletter-email" for="newsletter-email">
# <!-- <span class="arrow arrow-orange"><img src="/app/themes/oikio/dist/images/arrow-right.svg" /></span> -->
# <input class="oikio-input" id="newsletter-email" name="newsletter-email" placeholder="Sähköpostiosoite" required="" type="email" value=""/>
# <input class="oikio-submit" type="submit" value=""/>
# </label>
# <p class="newsletter-form-text">Kuukausittainen Algoritmi-uutiskirjeemme sisältää alan tärkeimpiä uutisia sekä asiantuntijoidemme näkemyksiä.</p>
# </form>
# </div>
# <div class="col-xs-12 col-lg-4 footer-col">
# <h4 class="footer-title">Yhteystiedot</h4>
# <ul class="footer-contacts">
# <li><span class="address-icon icon"></span>Eerikinkatu 27, (4.krs), 00180 Helsinki, Finland</li>
# <li><span class="phone-icon icon"></span>Niilo Relander <a href="tel:+358 40 571 2888">+358 40 571 2888</a></li>
# <li><span class="mail-icon icon"></span>etunimi.sukunimi@oikio.fi</li>
# </ul>
# </div>
# <div class="col-xs-12 col-lg-4 footer-col">
# <h4 class="footer-title">Seuraa meitä</h4>
# <ul class="footer-some-links">
# <li><a class="some-link facebook" href="https://www.facebook.com/oikioagency"><img src="/app/themes/oikio/dist/images/facebook.svg"/></a></li> <li><a class="some-link twitter" href="https://twitter.com/oikioagency"><img src="/app/themes/oikio/dist/images/twitter.svg"/></a></li> <li><a class="some-link instagram" href="https://www.instagram.com/oikioagency/"><img src="/app/themes/oikio/dist/images/instagram.svg"/></a></li> <li><a class="some-link linkedin" href="https://www.linkedin.com/company/oikio-digital-performance-agency/"><img src="/app/themes/oikio/dist/images/linkedin-linkki.svg"/></a></li> </ul>
# </div>
# </div>
# </div>
# <div id="footer-scroller" style="background-image: url('/app/themes/oikio/dist/images/oikiostrip.svg')"></div>
# </footer>
# <!-- Instagram Feed JS -->
# <script type="text/javascript">
# var sbiajaxurl = "https://oikio.fi/wp-admin/admin-ajax.php";
# </script>
# <script src="https://code.jquery.com/jquery-1.12.4-wp.min.js"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var sb_instagram_js_options = {"sb_instagram_at":"","font_method":"svg"};
# /* ]]> */
# </script>
# <script>(window.jQuery && jQuery.noConflict()) || document.write('<script src="/wp-includes/js/jquery/jquery.js"><\/script>')</script>
# <script src="/wp-content/plugins/instagram-feed/js/sb-instagram.min.js?ver=1.10.2"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var objectL10n = {"redirect_page":"https:\/\/oikio.fi\/kiitos-yhteydenottopyynnosta\/","redirect_page_rekry":"https:\/\/oikio.fi\/kiitos-hakemuksesta\/","redirect_page_newsletter":"https:\/\/oikio.fi\/kiitos-tilauksesta\/","contact_webhook":"https:\/\/hooks.zapier.com\/hooks\/catch\/1862021\/x2inya\/","rekry_webhook":"https:\/\/hooks.zapier.com\/hooks\/catch\/1862021\/x805di\/","newsletter_webhook":"https:\/\/hooks.zapier.com\/hooks\/catch\/1862021\/xkk7h4\/"};
# /* ]]> */
# </script>
# <script src="/wp-content/themes/oikio/dist/scripts/main-88fcee7d79.js"></script>

# %%
soup.title
# Out:
# <title>Tutustu asiantuntijatiimiimme » OIKIO</title>

# %%
henkilo_div = soup.find_all('div', class_ = 'single-person')

for henkilo in henkilo_div:
    spanit = henkilo.find_all('span')
    nimi = spanit[0].text
    titteli = spanit[1].text
    print(nimi, ":  ", titteli)
# Out:
# Taru Paavola :   Junior Paid Social & Programmatic Consultant
# Aleksi Rastas :   Senior Web Analyst
# Jyri Vuorinen :   Senior Web Analyst
# Selja Selenius :   Lead Programmatic Consultant
# Krista Tikka :   Lead Paid Social Consultant
# Ilpo Ryynänen :   Head of Data & Programmatic
# Iiris Lagus :   SEO Consultant
# Essi Martevo :   SEO Consultant
# Frans Astala :   SEO Consultant
# Henri Tamminen :   SEO Consultant
# Joonas Kantoluoto :   SEO Consultant
# Satu Brandt :   SEO Consultant & Team Lead
# Emilia Lahti :   SEO Consultant
# Joona Tuunanen :   Head of SEO
# Jaani Saulamaa :   PPC Consultant
# Iiro Heiskanen :   PPC Consultant
# Jaana Räsänen :   PPC Consultant
# Joonas Savolainen :   PPC Consultant
# Joachim Granberg :   Senior PPC Consultant
# Mirkka Mussalo :   PPC Consultant & Team Lead
# Saad Hafeez :   PPC Consultant
# Juha Viherväs :   Head of PPC
# Satu Tamminen :   Business Controller
# Niilo Relander :   CEO
